# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### P1. Write a Python code to output the following graph. (or a similar one)
# ```
# The productivity values for the 3 groups are the following:
#
# g1 = [80, 60, 80, 67, 34]
# g2 = [45, 67, 23, 89, 10]
# g3 = [30, 90, 50, 20, 90]
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from pandas import DataFrame

g1 = [80, 60, 80, 67, 34]
g2 = [45, 67, 23, 89, 10]
g3 = [30, 90, 50, 20, 90]

a=np.array([g1,g2,g3])
df=DataFrame(a, columns=['M','T','Th','W','F'], index=['Group 1', 'Group 2', 'Group 3'])

print(df.T.plot(kind='bar'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# ### P2. Write a Python code to output the following graph. (or a similar one)
# ```
# Draw 25 dots. Generate random x and y coordinates (integers from 1 to 30), random colors and random sizes (integers from 20 to 500) for the dots.
# ```
#
# ```
# Նկարեք 25 կետեր. Կետերի համար գեներացրեք պատահական x և y կոորդինատներ (1-ից 30 միջակայքում int տիպի թվեր), պատահական գույներ ու պատահական չափսեր (20-ից 500 միջակայքում int տիպի թվեր)։
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from random import randint
import matplotlib.pyplot as plt
import numpy as np
import random


fig = plt.figure()

ax = fig.add_subplot()
colors = ['red', 'green', 'purple', 'black', 'orange', 'yellow', 'k']
i = 0

for x in range(30):
    c = randint(5,5)
    plt.plot(1, 1)
x = np.random.randn(50)
y = np.random.randn(50) 

ax.scatter(x, y, color=colors[random.randrange(0,6)])
sizes = (np.random.sample(size=x.size) * 20) ** 2
ax.scatter(x, y, s=sizes, color=colors[random.randrange(0,6)])
plt.show()
